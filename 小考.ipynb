# %%
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot
import numpy as np
import math

import warnings
warnings.filterwarnings('ignore')

from IPython.html.widgets import interact, interact_manual, fixed
from IPython.html import widgets
from IPython.display import display

PI2 = 2 * math.pi

# %% [markdown]
# 第一題：

# %%
class LCPSawtoothSignal(thinkdsp.Sinusoid):
    """Represents a sawtooth signal."""
    
    def evaluate(self, ts):
        """Evaluates the signal at the given times.

        ts: float array of times
        
        returns: float wave array
        """
        cycles = self.freq * ts + self.offset / PI2
        frac, _ = np.modf(cycles)
        ys = thinkdsp.normalize(thinkdsp.unbias(frac), self.amp)
        return ys

# %%
sawtooth = LCPSawtoothSignal().make_wave(duration=0.5, framerate=40000)
sawtooth.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 第二題：

# %%
sawtooth=thinkdsp.SawtoothSignal(freq=1000,amp=10)
sawtooth.plot()

# %% [markdown]
# 第三題：

# %%
sawtooth = thinkdsp.SawtoothSignal(1000,amp=10).make_wave(duration=0.5,framerate=10000)
sawtooth.make_spectrum().plot()
